# %%
import numpy as np
import pandas as pd

# %%
data = [{"Drink": "Brewed coffe", "Type": "Hot", "Calories": 4, "Sugars (g)": 0, "Caffeine(mg)":260 }]
df = pd.DataFrame(data)

# %%
df.loc[1]={
# Out:
# Drink           Brewed coffe
# Type                     Hot
# Calories                   4
# Sugars (g)                 0
# Caffeine(mg)             260
# Name: 0, dtype: object
